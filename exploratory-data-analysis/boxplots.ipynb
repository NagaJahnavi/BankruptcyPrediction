# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/taiwanese-bankruptcy-prediction.csv')

# %% [markdown]
# individual box plots

# %%
for i in range(len(df.columns)):
  df.boxplot(column=df.columns[i], by='Bankrupt?', widths=0.5)
  # plt.savefig(f"./figures/{df.columns[i].replace('/', '_')}-boxplot.png")
# Out:
# /home/elizabeth/.local/lib/python3.10/site-packages/pandas/plotting/_matplotlib/tools.py:224: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(**fig_kw)
