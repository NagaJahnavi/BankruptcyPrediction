# %%
import pandas as pd
from sklearn.decomposition import PCA

# %%
data = pd.read_csv('../data/taiwanese-bankruptcy-prediction.csv')

# %%
data.describe()
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                        6819.000000
# mean      0.032263                                           0.505180
# std       0.176710                                           0.060686
# min       0.000000                                           0.000000
# 25%       0.000000                                           0.476527
# 50%       0.000000                                           0.502706
# 75%       0.000000                                           0.535563
# max       1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# 25%                                   0.535543
# ...

# %%
for col in data.columns:
    na_count = sum(data[col].isna())
    print(f"Na Values for {col}: {na_count}")

#print(data.columns)
# Out:
# Na Values for Bankrupt?: 0
# Na Values for  ROA(C) before interest and depreciation before interest: 0
# Na Values for  ROA(A) before interest and % after tax: 0
# Na Values for  ROA(B) before interest and depreciation after tax: 0
# Na Values for  Operating Gross Margin: 0
# Na Values for  Realized Sales Gross Margin: 0
# Na Values for  Operating Profit Rate: 0
# Na Values for  Pre-tax net Interest Rate: 0
# Na Values for  After-tax net Interest Rate: 0
# Na Values for  Non-industry income and expenditure/revenue: 0
# Na Values for  Continuous interest rate (after tax): 0
# Na Values for  Operating Expense Rate: 0
# Na Values for  Research and development expense rate: 0
# Na Values for  Cash flow rate: 0
# Na Values for  Interest-bearing debt interest rate: 0
# Na Values for  Tax rate (A): 0
# Na Values for  Net Value Per Share (B): 0
# Na Values for  Net Value Per Share (A): 0
# Na Values for  Net Value Per Share (C): 0
# Na Values for  Persistent EPS in the Last Four Seasons: 0
# ...

# %%
print(data.shape)
# Out:
# (6819, 96)

# %%
print(len(data.loc[data['Bankrupt?'] == 0]))
print(len(data.loc[data['Bankrupt?'] == 1]))
# Out:
# 6599
# 220

# %%
col_uniq = {col: len(data[col].unique()) for col in data.columns}

for k,v in col_uniq.items():
    print(f"Unique Values for '{k}': {v}")
# Out:
# Unique Values for 'Bankrupt?': 2
# Unique Values for ' ROA(C) before interest and depreciation before interest': 3333
# Unique Values for ' ROA(A) before interest and % after tax': 3151
# Unique Values for ' ROA(B) before interest and depreciation after tax': 3160
# Unique Values for ' Operating Gross Margin': 3781
# Unique Values for ' Realized Sales Gross Margin': 3788
# Unique Values for ' Operating Profit Rate': 3376
# Unique Values for ' Pre-tax net Interest Rate': 3789
# Unique Values for ' After-tax net Interest Rate': 3604
# Unique Values for ' Non-industry income and expenditure/revenue': 2551
# Unique Values for ' Continuous interest rate (after tax)': 3617
# Unique Values for ' Operating Expense Rate': 2966
# Unique Values for ' Research and development expense rate': 1536
# Unique Values for ' Cash flow rate': 5557
# Unique Values for ' Interest-bearing debt interest rate': 1080
# Unique Values for ' Tax rate (A)': 2488
# ...
